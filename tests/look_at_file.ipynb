# %%
import pandas as pd
import pyarrow

# %%
import pandas as pd
df = pd.read_parquet('../data/MEDS/SP_1/shard_events/admissions/[0-160).parquet', engine='pyarrow')
df
# Out:
#                                                   code  subject_id  \
# 0                                  IN/TYPE/Indlæggelse           8
# 1                                  IN/TYPE/Indlæggelse           6
# 2                                  IN/TYPE/Indlæggelse          25
# 3                            IN/TYPE/Tilbage fra orlov          22
# 4                                     IN/TYPE/Flyt_ind          15
# ..                                                 ...         ...
# 155  OUT/SECTION/NOH COAC0821, ØJENAFD. AMBULATORIE...          15
# 156                                  OUT/SECTION/NEFRO           2
# 157                                  OUT/SECTION/NEFRO           2
# 158                                 OUT/SECTION/CARDIO          20
# 159                                  OUT/SECTION/NEFRO          12
#
#                timestamp
# 0    1992-01-26 00:00:00
# 1    2017-02-06 00:00:00
# 2    2001-06-11 00:00:00
# 3    2015-10-06 00:00:00
# 4    2007-01-30 00:00:00
# ...

# %%
df = pd.read_parquet('../data/MEDS/SP_1/data/held_out/0.parquet', engine='pyarrow')
df
# Out:
#     subject_id                time  \
# 0           15                 NaT
# 1           15 1971-02-12 00:00:00
# 2           15 1978-06-18 02:01:39
# 3           15 1980-01-28 00:56:46
# 4           15 1980-03-29 00:00:00
# 5           15 1981-11-07 03:18:38
# 6           15 1982-11-07 00:00:00
# 7           15 1993-04-22 05:28:25
# 8           15 1994-12-27 20:12:38
# 9           15 2003-05-12 00:55:22
# 10          15 2003-08-26 12:11:37
# 11          15 2007-01-30 00:00:00
# 12          15 2010-12-18 23:07:35
# 13          15 2015-01-23 23:13:52
# 14          15 2016-10-31 07:28:22
# 15          15 2018-11-14 06:12:54
# 16          15 2020-06-24 00:00:00
# 17          15 2020-12-23 20:19:32
# 18          20                 NaT
# 19          20 1971-04-07 16:01:05
# 20          20 1977-07-21 20:14:39
# 21          20 1986-04-24 22:14:54
# 22          20 1990-05-26 00:00:00
# 23          20 1990-10-05 00:00:00
# 24          20 1992-09-24 05:27:58
# ...

# %%
df[df['subject_id'] == 15]
# Out:
#     subject_id                time  \
# 0           15                 NaT
# 1           15 1971-02-12 00:00:00
# 2           15 1978-06-18 02:01:39
# 3           15 1980-01-28 00:56:46
# 4           15 1980-03-29 00:00:00
# 5           15 1981-11-07 03:18:38
# 6           15 1982-11-07 00:00:00
# 7           15 1993-04-22 05:28:25
# 8           15 1994-12-27 20:12:38
# 9           15 2003-05-12 00:55:22
# 10          15 2003-08-26 12:11:37
# 11          15 2007-01-30 00:00:00
# 12          15 2010-12-18 23:07:35
# 13          15 2015-01-23 23:13:52
# 14          15 2016-10-31 07:28:22
# 15          15 2018-11-14 06:12:54
# 16          15 2020-06-24 00:00:00
# 17          15 2020-12-23 20:19:32
#
#                                                code  numeric_value
# 0                                         GENDER//K            NaN
# 1                                               DOB            NaN
# 2                                          P//PK766            NaN
# ...
